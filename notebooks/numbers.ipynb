# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import database models and functions
from src.database.base import init_db, get_db_session
from src.database.companies import Company
from src.database.financial_concepts import FinancialConcept
from src.database.financial_values import FinancialValue

# Import ingestion functionality
from src.ingestion.edgar_db.accessors import get_company, get_10k_filing
from src.ingestion.ingestion_helpers import ingest_financial_data

# Import logging and config
from src.utils.logging import get_logger
from src.utils.config import settings

# Set up plotting
plt.style.use('default')
sns.set_palette('husl')

logger = get_logger(__name__)

# %%
# Initialize database connection
try:
    engine, db_session = init_db(settings.database.url)
    print("✅ Database connection established successfully")
except Exception as e:
    print(f"❌ Failed to connect to database: {e}")
    print("Please check your database configuration")
# Out:
# 2025-08-05 01:25:07 [debug    ] database_initialized
# ✅ Database connection established successfully

# %%
# Get basic counts from the database
session = get_db_session()

total_companies = session.query(Company).count()
total_financial_concepts = session.query(FinancialConcept).count()
total_financial_values = session.query(FinancialValue).count()

print("📊 Database Overview:")
print(f"   Companies: {total_companies:,}")
print(f"   Financial Concepts: {total_financial_concepts:,}")
print(f"   Financial Values: {total_financial_values:,}")
print(f"   Average Financial Values per Company: {total_financial_values/total_companies:.1f}" if total_companies > 0 else "   No companies found")
# Out:
# 📊 Database Overview:
#    Companies: 64
#    Financial Concepts: 1,307
#    Financial Values: 32,100
#    Average Financial Values per Company: 501.6

# %%
# Find companies with no financial values
try:
    session = get_db_session()

    # Query companies with no financial values using LEFT JOIN
    companies_without_values = session.query(Company).outerjoin(
        FinancialValue, Company.id == FinancialValue.company_id
    ).filter(FinancialValue.company_id.is_(None)).all()

    print("🔍 Companies Missing Financial Values:")
    print(f"   Count: {len(companies_without_values):,}")
    print(f"   Percentage: {len(companies_without_values)/total_companies*100:.1f}%" if total_companies > 0 else "   No companies to analyze")

    # Create a DataFrame for analysis
    if companies_without_values:
        missing_values_df = pd.DataFrame([{
            'company_id': str(company.id),
            'name': company.name,
            'display_name': company.display_name,
            'cik': company.cik,
            'tickers': ', '.join(company.tickers) if company.tickers else None,
            'exchanges': ', '.join(company.exchanges) if company.exchanges else None,
            'sic': company.sic,
            'entity_type': company.entity_type
        } for company in companies_without_values])

        print("\n📋 Sample of companies without financial values:")
        print(missing_values_df[['name', 'tickers', 'cik', 'sic']].head(10).to_string(index=False))
    else:
        print("   All companies have financial values!")
        missing_values_df = pd.DataFrame()

except Exception as e:
    print(f"❌ Error analyzing companies without financial values: {e}")
    missing_values_df = pd.DataFrame()
# Out:
# 🔍 Companies Missing Financial Values:
#    Count: 13
#    Percentage: 20.3%
#
# 📋 Sample of companies without financial values:
#                            name            tickers     cik  sic
#                Nu Holdings Ltd.                 NU 1691493 6199
#             CENOVUS ENERGY INC. CVE, CNVEF, CVE-WT 1475260 1311
#               KINROSS GOLD CORP         KGC, KGCRF  701818 1040
#                     Kenvue Inc.               KVUE 1944048 2844
#                     NETFLIX INC               NFLX 1065280 7841
#                  GameStop Corp.                GME 1326380 5734
#         SoFi Technologies, Inc.               SOFI 1818874 6199
#          Permian Resources Corp                 PR 1658566 1311
#          Quantum Computing Inc.               QUBT 1758009 7372
# RECURSION PHARMACEUTICALS, INC.               RXRX 1601830 2836

# %%
# Find filings that don't have FinancialValues


from src.database.companies import list_all_companies
from src.database.filings import get_filings_by_company


all_companies = list_all_companies(offset=0, limit=100)
# Out:
# 2025-08-05 01:25:07 [info     ] list_all_companies             limit=100 offset=0 result_count=60

# %%
# all_companies = [get_company_by_ticker('GOOGL')]
filings_without_values = []
for company in all_companies:
    print(company.tickers[0])
    all_filings = get_filings_by_company(company.id)
    print(len(all_filings))

    # Filter to get only filings that don't have any financial values
    for filing in all_filings:
        value_count = session.query(FinancialValue).filter(
            FinancialValue.filing_id == filing.id
        ).count()
        if value_count == 0:
            filings_without_values.append(filing)
# Out:
# AMD
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AES
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AGNC
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# GOOGL
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AMZN
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AAL
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AAPL
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# APLD
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=3
# 3
# ACHR
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# T
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AUR
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# BAC
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# BA
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# AVGO
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# CCL
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# CSCO
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# CLSK
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# CLF
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# CDE
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# XOM
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# F
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# GME
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# HL
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# HPE
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# HBANP
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# INTC
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# IPG
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# IONQ
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# JOBY
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# KVUE
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=2
# 2
# LCID
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# MARA
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# MU
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# MSFT
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# MP
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# SMR
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# NVDA
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# ORCL
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# PLTR
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# PR
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# PFE
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# PCG
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# QUBT
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# RXRX
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# RIOT
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# HOOD
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# RKT
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# RKLB
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# S
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# SNAP
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# SOFI
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# SMCI
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=4
# 4
# TSLA
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# RIG
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# UBER
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# UNH
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# VZ
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# WMT
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# WBD
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5
# WFC
# 2025-08-05 01:25:07 [info     ] retrieved_filings_by_company   count=5
# 5

# %%
filings_without_values
# Out:
# []

# %%
for filing in filings_without_values:
    edgar_company = get_company(company.tickers[0])
    edgar_filing = get_10k_filing(edgar_company, filing.period_of_report.year)
    ingest_financial_data(company.id, filing.id, edgar_filing)

# %%
len(filings_without_values)
# Out:
# 0

# %%
# Re-run analysis after ingestion to see improvements
def analyze_ingestion_impact():
    """Analyze the impact of financial data ingestion."""
    try:
        session = get_db_session()

        # Get updated counts
        new_total_companies = session.query(Company).count()
        new_total_concepts = session.query(FinancialConcept).count()
        new_total_values = session.query(FinancialValue).count()

        # Get companies still missing financial values
        companies_still_missing = session.query(Company).outerjoin(
            FinancialValue, Company.id == FinancialValue.company_id
        ).filter(FinancialValue.company_id.is_(None)).count()

        print("🔄 Updated Database Statistics:")
        print(f"   Companies: {new_total_companies:,}")
        print(f"   Financial Concepts: {new_total_concepts:,} (+{new_total_concepts - total_financial_concepts})")
        print(f"   Financial Values: {new_total_values:,} (+{new_total_values - total_financial_values})")
        print(f"   Companies still missing financial data: {companies_still_missing:,}")

        if new_total_values > total_financial_values:
            improvement = ((total_companies - companies_still_missing) / total_companies) * 100
            print(f"   📈 Financial data coverage improved to {improvement:.1f}%")

        return {
            'new_concepts': new_total_concepts - total_financial_concepts,
            'new_values': new_total_values - total_financial_values,
            'companies_still_missing': companies_still_missing
        }

    except Exception as e:
        print(f"❌ Error analyzing ingestion impact: {e}")
        return None

# Run impact analysis if ingestion was performed
print("\n📊 Analyzing impact of financial data ingestion...")
impact = analyze_ingestion_impact()
# Out:
# 📊 Analyzing impact of financial data ingestion...
# 🔄 Updated Database Statistics:
#    Companies: 64
#    Financial Concepts: 1,307 (+0)
#    Financial Values: 32,100 (+0)
#    Companies still missing financial data: 13

# %%
# Get comprehensive overview of financial concepts
session = get_db_session()

# Get all financial concepts with usage statistics
concepts_query = session.query(FinancialConcept).all()

if concepts_query:
    print("💰 Financial Concepts Overview:")
    print(f"   Total financial concepts: {len(concepts_query):,}")

    # Create detailed DataFrame for analysis
    concepts_data = []
    for concept in concepts_query:
        # Count financial values for this concept
        value_count = session.query(FinancialValue).filter(
            FinancialValue.concept_id == concept.id
        ).count()

        # Count unique companies using this concept
        company_count = session.query(FinancialValue.company_id).filter(
            FinancialValue.concept_id == concept.id
        ).distinct().count()

        # Count unique filings using this concept
        filing_count = session.query(FinancialValue.filing_id).filter(
            FinancialValue.concept_id == concept.id,
            FinancialValue.filing_id.isnot(None)
        ).distinct().count()

        concepts_data.append({
            'id': str(concept.id),
            'name': concept.name,
            'description': concept.description,
            'labels_count': len(concept.labels) if concept.labels else 0,
            'labels': ', '.join(concept.labels[:3]) + ('...' if len(concept.labels) > 3 else '') if concept.labels else None,
            'total_values': value_count,
            'companies_using': company_count,
            'filings_using': filing_count,
            'coverage_pct': (company_count / total_companies * 100) if total_companies > 0 else 0
        })

    concepts_df = pd.DataFrame(concepts_data)
    concepts_df = concepts_df.sort_values('total_values', ascending=False)

    print("\n📊 Financial Concepts Statistics:")
    print(f"   Concepts with no usage: {len(concepts_df[concepts_df['total_values'] == 0])}")
    print(f"   Concepts with 1-10 values: {len(concepts_df[(concepts_df['total_values'] >= 1) & (concepts_df['total_values'] <= 10)])}")
    print(f"   Concepts with 11-100 values: {len(concepts_df[(concepts_df['total_values'] >= 11) & (concepts_df['total_values'] <= 100)])}")
    print(f"   Concepts with 100+ values: {len(concepts_df[concepts_df['total_values'] > 100])}")
    print(f"   Average values per concept: {concepts_df['total_values'].mean():.1f}")
    print(f"   Median values per concept: {concepts_df['total_values'].median():.1f}")

else:
    print("   No financial concepts found in database")
    concepts_df = pd.DataFrame()
# Out:
# 💰 Financial Concepts Overview:
#    Total financial concepts: 1,307
# 📊 Financial Concepts Statistics:
#    Concepts with no usage: 191
#    Concepts with 1-10 values: 885
#    Concepts with 11-100 values: 111
#    Concepts with 100+ values: 120
#    Average values per concept: 24.6
#    Median values per concept: 1.0

# %%
# Categorize financial concepts by common patterns
if not concepts_df.empty:
    print("📋 Financial Concepts Categorization:")

    # Analyze concept names for common patterns
    concept_names = concepts_df['name'].tolist()

    # Common financial statement categories
    categories = {
        'Assets': [name for name in concept_names if any(keyword in name.lower() for keyword in ['asset', 'cash', 'inventory', 'receivable', 'equipment', 'property'])],
        'Liabilities': [name for name in concept_names if any(keyword in name.lower() for keyword in ['liability', 'liabilities', 'payable', 'debt', 'loan', 'obligation'])],
        'Equity': [name for name in concept_names if any(keyword in name.lower() for keyword in ['equity', 'capital', 'retained', 'shareholder', 'stockholder'])],
        'Revenue': [name for name in concept_names if any(keyword in name.lower() for keyword in ['revenue', 'sales', 'income', 'earning', 'proceed'])],
        'Expenses': [name for name in concept_names if any(keyword in name.lower() for keyword in ['expense', 'cost', 'depreciation', 'amortization', 'paid', 'payment'])],
        'Cash Flow': [name for name in concept_names if any(keyword in name.lower() for keyword in ['cash flow', 'operating activities', 'investing activities', 'financing activities'])],
        'Shares': [name for name in concept_names if any(keyword in name.lower() for keyword in ['shares', 'share', 'outstanding', 'weighted'])],
        'Per Share': [name for name in concept_names if any(keyword in name.lower() for keyword in ['per share', 'eps', 'earnings per'])],
    }

    for category, names in categories.items():
        if names:
            # Get usage stats for this category
            category_concepts = concepts_df[concepts_df['name'].isin(names)]
            total_values = category_concepts['total_values'].sum()
            avg_usage = category_concepts['total_values'].mean()

            print(f"\n   📊 {category} ({len(names)} concepts):")
            print(f"      Total values: {total_values:,}")
            print(f"      Avg values per concept: {avg_usage:.1f}")
            print(f"      Concepts: {', '.join(names)}")


    # Find uncategorized concepts
    all_categorized = set()
    for names in categories.values():
        all_categorized.update(names)

    uncategorized = [name for name in concept_names if name not in all_categorized]
    if uncategorized:
        uncategorized_concepts = concepts_df[concepts_df['name'].isin(uncategorized)]
        print(f"\n   ❓ Uncategorized ({len(uncategorized)} concepts):")
        print(f"      Total values: {uncategorized_concepts['total_values'].sum():,}")
        print(f"      Concepts: {', '.join(uncategorized)}")
else:
    print("⚠️  No concepts data available for categorization")
# Out:
# 📋 Financial Concepts Categorization:
#
#    📊 Assets (298 concepts):
#       Total values: 5,791
#       Avg values per concept: 19.4
#       Concepts: us-gaap_Assets, us-gaap_NetCashProvidedByUsedInOperatingActivities, us-gaap_NetCashProvidedByUsedInInvestingActivities, us-gaap_NetCashProvidedByUsedInFinancingActivities, us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect, us-gaap_OtherNoncashIncomeExpense, us-gaap_IncreaseDecreaseInOtherOperatingAssets, us-gaap_OtherAssets, us-gaap_DerivativeAssets, us-gaap_CashAndDueFromBanks, us-gaap_EquipmentExpense, us-gaap_LoansReceivableHeldForSaleNetNotPartOfDisposalGroup, us-gaap_IncreaseDecreaseInDerivativeAssetsAndLiabilities, us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents, us-gaap_PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization, us-gaap_ServicingAsset, us-gaap_LoansAndLeasesReceivableAllowance, us-gaap_LoansAndLeasesReceivableNetReportedAmount, us-gaap_NotesReceivableGross, wfc_ProceedsFromSaleOfForeclosedAssetsAndShortSales, us-gaap_PropertyPlantAndEquipmentNet, wfc_FinancingReceivableAndNetInvestmentInLeaseExcludingAccruedInterestAfterAllowanceForCreditLoss, wfc_FinancingReceivableAndNetInvestmentInLeaseExcludingAccruedInterestBeforeAllowanceForCreditLoss, wfc_FinancingReceivableAndNetInvestmentInLeaseAllowanceForLoanLossesExcludingAccruedInterest, us-gaap_CashAndCashEquivalentsAtCarryingValue, us-gaap_AssetsCurrent, us-gaap_OtherAssetsNoncurrent, us-gaap_PaymentsToAcquirePropertyPlantAndEquipment, us-gaap_AccountsReceivableNetCurrent, us-gaap_AmortizationOfIntangibleAssets, us-gaap_IncreaseDecreaseInAccountsReceivable, us-gaap_ServicingAssetAtFairValueAmount, us-gaap_LoansAndLeasesReceivableNetOfDeferredIncome, us-gaap_InventoryNet, us-gaap_ServicingAssetAtAmortizedValue, us-gaap_OperatingLeaseRightOfUseAsset, us-gaap_OtherAssetsCurrent, us-gaap_IntangibleAssetsNetExcludingGoodwill, us-gaap_EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents, us-gaap_IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets, us-gaap_PrepaidExpenseAndOtherAssetsCurrent, us-gaap_DeferredIncomeTaxAssetsNet, us-gaap_PaymentsToAcquireBusinessesNetOfCashAcquired, us-gaap_CashCashEquivalentsAndShortTermInvestments, us-gaap_FiniteLivedIntangibleAssetsNet, us-gaap_IncreaseDecreaseInOtherNoncurrentAssets, us-gaap_IncreaseDecreaseInOtherCurrentAssets, us-gaap_RightOfUseAssetObtainedInExchangeForOperatingLeaseLiability, us-gaap_OtherOperatingActivitiesCashFlowStatement, us-gaap_ProceedsFromSaleOfPropertyPlantAndEquipment, us-gaap_GainLossOnSaleOfPropertyPlantEquipment, us-gaap_ReceivablesNetCurrent, us-gaap_OperatingLeaseRightOfUseAssetAmortizationExpense, us-gaap_EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations, us-gaap_PaymentsToAcquireProductiveAssets, goog_AcquisitionsNetOfCashAcquiredAndPurchasesOfIntangibleAndOtherAssets, goog_AmortizationAndImpairmentOfIntangibleAssets, goog_DepreciationAndImpairmentOnDispositionOfPropertyAndEquipment, msft_AcquisitionsNetOfCashAcquiredAndPurchasesOfIntangibleAndOtherAssets, us-gaap_AssetsOfDisposalGroupIncludingDiscontinuedOperationCurrent, us-gaap_InventoryWriteDown, us-gaap_AssetImpairmentCharges, us-gaap_NoncashOrPartNoncashAcquisitionFixedAssetsAcquired1, us-gaap_PensionAndOtherPostretirementBenefitsExpenseReversalOfExpenseNoncash, us-gaap_AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment, us-gaap_IncreaseDecreaseInReceivables, us-gaap_CashAcquiredFromAcquisition, us-gaap_IncomeTaxesReceivable, us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect, us-gaap_OtherReceivables, us-gaap_RestrictedCashAndCashEquivalentsAtCarryingValue, us-gaap_IncreaseDecreaseInFinanceReceivables, us-gaap_NotesAndLoansReceivableNetCurrent, us-gaap_RestrictedCash, us-gaap_GainLossOnDispositionOfAssets1, us-gaap_AdjustmentsToReconcileNetIncomeLossToCashProvidedByUsedInOperatingActiviti ...
#
#    📊 Liabilities (307 concepts):
#       Total values: 8,585
#       Avg values per concept: 28.0
#       Concepts: us-gaap_LiabilitiesAndStockholdersEquity, us-gaap_Liabilities, us-gaap_RepaymentsOfLongTermDebt, us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt, us-gaap_ProceedsFromSaleOfAvailableForSaleSecuritiesDebt, us-gaap_ProceedsFromRepaymentsOfShortTermDebt, us-gaap_PaymentsToAcquireLoansAndLeasesHeldForInvestment, us-gaap_DerivativeLiabilities, us-gaap_LongTermDebt, us-gaap_ProvisionForLoanLeaseAndOtherLosses, us-gaap_ProceedsFromSaleOfLoansAndLeasesHeldForInvestment, us-gaap_IncreaseDecreaseInOtherAccountsPayableAndAccruedLiabilities, us-gaap_LoansReceivableHeldForSaleNetNotPartOfDisposalGroup, us-gaap_TradingSecuritiesDebt, us-gaap_InterestIncomeDebtSecuritiesOperating, us-gaap_InterestExpenseLongTermDebt, us-gaap_InterestAndFeeIncomeLoansAndLeasesHeldInPortfolio, us-gaap_InterestBearingDepositLiabilities, us-gaap_NoninterestBearingDepositLiabilities, us-gaap_AccountsPayableAndAccruedLiabilitiesCurrentAndNoncurrent, wfc_PaymentsForLoansOriginatedByBankingSubsidiariesNetOfProceedsFromCollections, us-gaap_IncreaseDecreaseInDerivativeAssetsAndLiabilities, wfc_UnrealizedGainLossOnMortgageServicingRightsMortgagesHeldForSaleAndLoansHeldForSale, us-gaap_ProceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet, wfc_PrincipalCollectedOnNonbankEntitiesLoans, wfc_LoansOriginatedByNonbankEntities, us-gaap_InterestAndFeeIncomeLoansAndLeasesHeldForSale, us-gaap_DebtAndEquitySecuritiesRealizedGainLoss, us-gaap_AvailableForSaleSecuritiesDebtSecurities, us-gaap_LoansAndLeasesReceivableAllowance, us-gaap_LoansAndLeasesReceivableNetReportedAmount, us-gaap_PaymentsForOriginationAndPurchasesOfLoansHeldForSale, us-gaap_ProceedsFromSaleAndCollectionOfLoansHeldforsale, wfc_PaymentsforOriginationandpurchasesofMortgageLoansHeldforsale, us-gaap_DebtSecuritiesHeldToMaturityExcludingAccruedInterestAfterAllowanceForCreditLoss, us-gaap_DebtSecuritiesAvailableForSaleExcludingAccruedInterest, wfc_FinancingReceivableAndNetInvestmentInLeaseAllowanceForLoanLossesExcludingAccruedInterest, us-gaap_LiabilitiesCurrent, us-gaap_OtherLiabilitiesNoncurrent, us-gaap_DebtSecuritiesHeldToMaturityAmortizedCostAfterAllowanceForCreditLoss, wfc_DebtSecuritiesHeldToMaturityAmortizedCostAfterAllowanceForCreditLoss, us-gaap_AccountsPayableCurrent, us-gaap_IncreaseDecreaseInLoansHeldForSale, us-gaap_InterestIncomeExpenseAfterProvisionForLoanLoss, us-gaap_InterestAndFeeIncomeLoansHeldForSaleMortgages, us-gaap_LoansAndLeasesReceivableNetOfDeferredIncome, us-gaap_InterestAndFeeIncomeNonmortgageLoansAndLeasesHeldForSale, wfc_DebtSecuritiesGainLoss1, us-gaap_OtherLiabilitiesCurrent, us-gaap_IncreaseDecreaseInAccountsPayable, us-gaap_OperatingLeaseLiabilityNoncurrent, us-gaap_DeferredIncomeTaxLiabilitiesNet, us-gaap_AccruedLiabilitiesCurrent, us-gaap_LongTermDebtNoncurrent, us-gaap_ContractWithCustomerLiabilityCurrent, us-gaap_IncreaseDecreaseInContractWithCustomerLiability, us-gaap_EmployeeRelatedLiabilitiesCurrent, us-gaap_LongTermDebtAndCapitalLeaseObligations, us-gaap_IncreaseDecreaseInAccountsPayableAndAccruedLiabilities, us-gaap_ContractWithCustomerLiabilityNoncurrent, us-gaap_IncreaseDecreaseInOtherNoncurrentLiabilities, us-gaap_OperatingLeaseLiabilityCurrent, us-gaap_IncreaseDecreaseInAccruedLiabilities, us-gaap_DebtCurrent, us-gaap_LongTermDebtCurrent, us-gaap_ProceedsFromIssuanceOfLongTermDebt, us-gaap_IncreaseDecreaseInAccruedLiabilitiesAndOtherOperatingLiabilities, us-gaap_GainsLossesOnExtinguishmentOfDebt, us-gaap_IncreaseDecreaseInOtherOperatingLiabilities, us-gaap_LiabilitiesNoncurrent, us-gaap_AccountsPayableAndAccruedLiabilitiesCurrent, us-gaap_IncreaseDecreaseInAccruedIncomeTaxesPayable, us-gaap_RightOfUseAssetObtainedInExchangeForOperatingLeaseLiability, us-gaap_RepaymentsOfDebt, us-gaap_ProceedsFromDebtNetOfIssuanceCosts, us-gaap_IncreaseDecreaseInOtherCurrentLiabilities, us-gaap_AvailableForSaleSecuritiesDebtSecuritiesCurrent, us-gaap_DebtAndEquitySecuritiesGainLoss, us-gaap_IncreaseDecreaseInEmployeeRelatedLiabilities, us-gaap_RepaymentsOfDebtA ...
#
#    📊 Equity (85 concepts):
#       Total values: 3,210
#       Avg values per concept: 37.8
#       Concepts: us-gaap_LiabilitiesAndStockholdersEquity, us-gaap_RetainedEarningsAccumulatedDeficit, us-gaap_StockholdersEquity, us-gaap_AdditionalPaidInCapital, us-gaap_StockholdersEquityIncludingPortionAttributableToNoncontrollingInterest, us-gaap_NetIncomeLossAvailableToCommonStockholdersBasic, us-gaap_DividendIncomeEquitySecuritiesOperating, wfc_PaymentstoAcquireNotHeldForTradingEquitySecurities, us-gaap_EquitySecuritiesFvNiAndWithoutReadilyDeterminableFairValue, us-gaap_ProceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet, wfc_ProceedsfromSaleandCapitalReturnsofEquitySecuritiesNotHeldForTrading, us-gaap_DebtAndEquitySecuritiesRealizedGainLoss, us-gaap_ProceedsFromPaymentsToMinorityShareholders, wfc_GainsLossesFromEquityInvestments, us-gaap_IncomeLossFromEquityMethodInvestments, us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments, us-gaap_LongTermDebtAndCapitalLeaseObligations, us-gaap_CommonStocksIncludingAdditionalPaidInCapital, us-gaap_AdditionalPaidInCapitalCommonStock, us-gaap_EquityMethodInvestments, us-gaap_IncreaseDecreaseInOtherOperatingCapitalNet, us-gaap_CapitalExpendituresIncurredButNotYetPaid, us-gaap_ProceedsFromMinorityShareholders, us-gaap_IncomeLossFromEquityMethodInvestmentsNetOfDividendsOrDistributions, us-gaap_RedeemableNoncontrollingInterestEquityCarryingAmount, us-gaap_DebtAndEquitySecuritiesGainLoss, us-gaap_RepaymentsOfDebtAndCapitalLeaseObligations, us-gaap_RepaymentsOfLongTermDebtAndCapitalSecurities, us-gaap_IncreaseDecreaseInEquitySecuritiesFvNi, us-gaap_PaymentsToMinorityShareholders, us-gaap_LongTermDebtAndCapitalLeaseObligationsCurrent, us-gaap_ProceedsFromEquityMethodInvestmentDividendsOrDistributionsReturnOfCapital, us-gaap_CapitalLeaseObligationsIncurred, us-gaap_PaymentsToAcquireEquityMethodInvestments, us-gaap_NetIncomeLossAvailableToCommonStockholdersDiluted, us-gaap_EquitySecuritiesFvNi, aes_PaymentsForFinancedCapitalExpenditures, us-gaap_EquitySecuritiesFvNiGainLoss, lcid_FairValueAdjustmentOfForwardContractsIndexedToEquity, smr_PaymentsOfReverseRecapitalizationCosts, smr_NetIncomeLossAttributableToLegacyShareholdersPriorToReverseRecapitalization, agnc_ComprehensiveIncomeAvailableToCommonShareholders, smr_ConversionOfEquityOptionsToLiabilityAward, smr_ProceedsFromReverseRecapitalizationNet, ionq_NonCashReclassificationOfWarrantLiabilitiesToEquityUponExercise, ccl_AdjustmentsToReconcileNetIncomeLossToCashProvidedByUsedInOperatingActivitiesExcludingIncreaseDecreaseInOperatingCapital, us-gaap_BusinessCombinationConsiderationTransferredEquityInterestsIssuedAndIssuable, us-gaap_ProceedsFromIssuanceOrSaleOfEquity, hban_CapitalMarketsFeeIncome, aes_ReinvestmentofProceedsfromSaleofEquityMethodInvestments, us-gaap_RedeemableNoncontrollingInterestEquityCommonCarryingAmount, us-gaap_PaymentsForRepurchaseOfEquity, intc_EquityInvestments, ipg_IncomeLossfromContinuingOperationsbeforeEquityMethodInvestmentsandNoncontrollingInterest, mu_CapitalExpendituresIncurredOnPurchaseContractsNotYetPaid, us-gaap_RedeemableNoncontrollingInterestEquityFairValue, us-gaap_StockholdersEquityBeforeTreasuryStock, uber_AssetImpairmentChargesExcludingEquityMethodInvestments, us-gaap_EquityMethodInvestmentOtherThanTemporaryImpairment, us-gaap_DebtAndEquitySecuritiesUnrealizedGainLoss, aal_PaymentToAcquireEquitySecuritiesEquitySecuritiesFVNIAndEquitySecuritiesWithoutReadilyDeterminableFairValue, hpe_StockholdersEquityAttributabletoNoncontrollingInterestContinuingOperations, us-gaap_EquityMethodInvestmentDividendsOrDistributions, lcid_ProceedsFromReverseRecapitalization, lcid_PaymentOfReverseRecapitalizationTransactionCosts, lcid_ChangeInCapitalExpendituresIncurredButNotYetPaid, lcid_ExtinguishmentOfConvertiblePreferredStockIncludedInAdditionalPaidInCapital, lcid_CapitalContributionUponIssuanceOfPreferredShares, us-gaap_BusinessCombinationStepAcquisitionEquityInterestInAcquireeRemeasurementGain, lcid_FairValueAdjustmentOfForwardContractsIndexedToIssuersE ...
#
#    📊 Revenue (311 concepts):
#       Total values: 10,106
#       Avg values per concept: 32.5
#       Concepts: us-gaap_RetainedEarningsAccumulatedDeficit, us-gaap_EarningsPerShareBasic, us-gaap_EarningsPerShareDiluted, us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax, us-gaap_NetIncomeLoss, us-gaap_IncomeTaxExpenseBenefit, us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest, us-gaap_PaymentsForProceedsFromOtherInvestingActivities, us-gaap_ProceedsFromPaymentsForOtherFinancingActivities, us-gaap_OtherNoncashIncomeExpense, us-gaap_NetIncomeLossAttributableToNoncontrollingInterest, us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities, us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt, us-gaap_NetIncomeLossAvailableToCommonStockholdersBasic, us-gaap_InterestIncomeExpenseNet, us-gaap_ProceedsFromSaleOfAvailableForSaleSecuritiesDebt, us-gaap_ProceedsFromRepaymentsOfShortTermDebt, us-gaap_IncomeLossFromContinuingOperationsIncludingPortionAttributableToNoncontrollingInterest, us-gaap_IncreaseDecreaseInDeferredIncomeTaxes, us-gaap_NoninterestIncome, us-gaap_InterestAndDividendIncomeOperating, us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfHeldToMaturitySecurities, us-gaap_NoninterestIncomeOtherOperatingIncome, us-gaap_ProceedsFromSaleOfLoansAndLeasesHeldForInvestment, us-gaap_InterestIncomeDebtSecuritiesOperating, us-gaap_InterestAndFeeIncomeLoansAndLeasesHeldInPortfolio, us-gaap_DividendIncomeEquitySecuritiesOperating, wfc_PaymentsForLoansOriginatedByBankingSubsidiariesNetOfProceedsFromCollections, us-gaap_ProceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet, wfc_ProceedsfromSaleandCapitalReturnsofEquitySecuritiesNotHeldForTrading, us-gaap_IncomeTaxesPaidNet, us-gaap_RevenuesNetOfInterestExpense, us-gaap_InterestAndFeeIncomeLoansAndLeasesHeldForSale, us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax, us-gaap_AvailableForSaleSecuritiesDebtSecurities, us-gaap_InterestIncomeOther, us-gaap_ProceedsFromSaleAndCollectionOfLoansHeldforsale, us-gaap_ProceedsFromIssuanceOfPreferredStockAndPreferenceStock, us-gaap_ProceedsFromIssuanceOfCommonStock, us-gaap_ProceedsFromPaymentsToMinorityShareholders, us-gaap_OtherInterestAndDividendIncome, wfc_ProceedsFromSalesofandPaydownsonMortgagesOriginatedHeldForSale, us-gaap_RevenueFromContractWithCustomerIncludingAssessedTax, wfc_ProceedsFromSaleOfForeclosedAssetsAndShortSales, us-gaap_OperatingIncomeLoss, us-gaap_IncomeTaxesPaid, us-gaap_InterestIncomeExpenseAfterProvisionForLoanLoss, wfc_LeaseIncomeLessor, us-gaap_InterestAndFeeIncomeLoansHeldForSaleMortgages, us-gaap_LoansAndLeasesReceivableNetOfDeferredIncome, us-gaap_InterestAndFeeIncomeNonmortgageLoansAndLeasesHeldForSale, us-gaap_InsuranceServicesRevenue, us-gaap_OtherNonoperatingIncomeExpense, us-gaap_NonoperatingIncomeExpense, us-gaap_DeferredIncomeTaxLiabilitiesNet, us-gaap_DeferredIncomeTaxExpenseBenefit, us-gaap_DeferredIncomeTaxAssetsNet, us-gaap_Revenues, us-gaap_IncomeLossFromEquityMethodInvestments, us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments, us-gaap_DeferredIncomeTaxesAndTaxCredits, us-gaap_CostOfRevenue, us-gaap_AccruedIncomeTaxesCurrent, us-gaap_ProceedsFromSaleAndMaturityOfMarketableSecurities, us-gaap_AccruedIncomeTaxesNoncurrent, us-gaap_InvestmentIncomeInterest, us-gaap_ProceedsFromIssuanceOfLongTermDebt, us-gaap_IncreaseDecreaseInAccruedIncomeTaxesPayable, us-gaap_ProceedsFromStockOptionsExercised, us-gaap_ProceedsFromMinorityShareholders, us-gaap_ProceedsFromDebtNetOfIssuanceCosts, us-gaap_ProceedsFromSaleOfPropertyPlantAndEquipment, us-gaap_ProceedsFromIssuanceOfSharesUnderIncentiveAndShareBasedCompensationPlansIncludingStockOptions, us-gaap_IncomeLossFromEquityMethodInvestmentsNetOfDividendsOrDistributions, us-gaap_AvailableForSaleSecuritiesDebtSecuritiesCurrent, us-gaap_IncreaseDecreaseInIncomeTaxes, us-gaap_ProceedsFromSaleMaturityAndCollectionOfShorttermInvestments, msft_ProceedsFromInvestments, us-gaap_ProceedsFromSaleAndMaturityOfOtherInvestm ...
#
#    📊 Expenses (379 concepts):
#       Total values: 9,799
#       Avg values per concept: 25.9
#       Concepts: us-gaap_IncomeTaxExpenseBenefit, us-gaap_PaymentsForProceedsFromOtherInvestingActivities, us-gaap_PaymentsForRepurchaseOfCommonStock, us-gaap_ProceedsFromPaymentsForOtherFinancingActivities, us-gaap_OtherNoncashIncomeExpense, us-gaap_InterestExpense, us-gaap_InterestPaidNet, us-gaap_AdditionalPaidInCapital, us-gaap_PaymentsOfDividendsCommonStock, us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities, us-gaap_RepaymentsOfLongTermDebt, us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt, us-gaap_InterestIncomeExpenseNet, us-gaap_ProceedsFromRepaymentsOfShortTermDebt, us-gaap_PaymentsToAcquireLoansAndLeasesHeldForInvestment, us-gaap_OtherNoninterestExpense, us-gaap_NoninterestExpense, us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfHeldToMaturitySecurities, us-gaap_EquipmentExpense, us-gaap_InterestExpenseOther, us-gaap_PaymentsOfDividendsPreferredStockAndPreferenceStock, us-gaap_DepreciationAmortizationAndAccretionNet, us-gaap_InterestExpenseDeposits, us-gaap_InterestExpenseLongTermDebt, wfc_PaymentstoAcquireNotHeldForTradingEquitySecurities, wfc_PaymentsForLoansOriginatedByBankingSubsidiariesNetOfProceedsFromCollections, us-gaap_PaymentsToAcquireHeldToMaturitySecurities, us-gaap_IncomeTaxesPaidNet, wfc_UnearnedESOPSharesCost, us-gaap_PropertyPlantAndEquipmentAndFinanceLeaseRightOfUseAssetAfterAccumulatedDepreciationAndAmortization, us-gaap_MarketingAndAdvertisingExpense, us-gaap_RevenuesNetOfInterestExpense, us-gaap_CompensationExpenseExcludingCostOfGoodAndServiceSold, us-gaap_ProfessionalAndContractServicesExpense, us-gaap_InterestExpenseShortTermBorrowings, us-gaap_PaymentsForRepurchaseOfRedeemablePreferredStock, us-gaap_PaymentsForOriginationAndPurchasesOfLoansHeldForSale, us-gaap_PaymentsRelatedToTaxWithholdingForShareBasedCompensation, us-gaap_ProceedsFromPaymentsToMinorityShareholders, wfc_PaymentsforOriginationandpurchasesofMortgageLoansHeldforsale, wfc_InterestExpenseOrReversalOfInterestExpenseShortTermBorrowings, us-gaap_DebtSecuritiesHeldToMaturityAmortizedCostAfterAllowanceForCreditLoss, wfc_DebtSecuritiesHeldToMaturityAmortizedCostAfterAllowanceForCreditLoss, us-gaap_PaymentsToAcquirePropertyPlantAndEquipment, us-gaap_AmortizationOfIntangibleAssets, us-gaap_IncomeTaxesPaid, us-gaap_FederalDepositInsuranceCorporationPremiumExpense, us-gaap_InterestIncomeExpenseAfterProvisionForLoanLoss, us-gaap_OtherLaborRelatedExpenses, us-gaap_ResearchAndDevelopmentExpense, us-gaap_OtherNonoperatingIncomeExpense, us-gaap_CostOfGoodsAndServicesSold, us-gaap_NonoperatingIncomeExpense, us-gaap_SellingGeneralAndAdministrativeExpense, us-gaap_GeneralAndAdministrativeExpense, us-gaap_DeferredIncomeTaxExpenseBenefit, us-gaap_CostsAndExpenses, us-gaap_DepreciationDepletionAndAmortization, us-gaap_IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets, us-gaap_PrepaidExpenseAndOtherAssetsCurrent, us-gaap_PaymentsToAcquireBusinessesNetOfCashAcquired, us-gaap_SellingAndMarketingExpense, us-gaap_CommonStocksIncludingAdditionalPaidInCapital, us-gaap_OperatingExpenses, us-gaap_CostOfRevenue, us-gaap_PaymentsToAcquireMarketableSecurities, us-gaap_AdditionalPaidInCapitalCommonStock, us-gaap_DepreciationAndAmortization, us-gaap_PaymentsToAcquireInvestments, us-gaap_PaymentsToAcquireShortTermInvestments, us-gaap_CapitalExpendituresIncurredButNotYetPaid, us-gaap_RepaymentsOfDebt, us-gaap_ProceedsFromDebtNetOfIssuanceCosts, us-gaap_AmortizationOfFinancingCostsAndDiscounts, us-gaap_PrepaidExpenseCurrent, us-gaap_OperatingLeaseRightOfUseAssetAmortizationExpense, us-gaap_PaymentsToAcquireOtherInvestments, us-gaap_PaymentsToAcquireProductiveAssets, us-gaap_AccretionAmortizationOfDiscountsAndPremiumsInvestments, us-gaap_CostOfGoodsAndServiceExcludingDepreciationDepletionAndAmortization, us-gaap_OtherDepreciationAndAmortization, us-gaap_PaymentsOfDividends, us-gaap_RepaymentsOfDebtAndCapitalLeaseObligations, us-gaap_FinanceLeasePrincipalPayments, us-gaap_LaborAndRelatedExpense, us-gaap_RepaymentsOfLinesOfCredit ...
#
#    📊 Shares (53 concepts):
#       Total values: 1,982
#       Avg values per concept: 37.4
#       Concepts: us-gaap_EarningsPerShareBasic, us-gaap_EarningsPerShareDiluted, us-gaap_WeightedAverageNumberOfSharesOutstandingBasic, us-gaap_WeightedAverageNumberOfDilutedSharesOutstanding, dei_EntityCommonStockSharesOutstanding, wfc_UnearnedESOPSharesCost, us-gaap_PaymentsRelatedToTaxWithholdingForShareBasedCompensation, us-gaap_ProceedsFromPaymentsToMinorityShareholders, wfc_ShareBasedCompensationAndPreferredStockReleasedByEmployeeStockOptionPlan, us-gaap_ShareBasedCompensation, us-gaap_ProceedsFromMinorityShareholders, us-gaap_CommonStockSharesAuthorized, us-gaap_ProceedsFromIssuanceOfSharesUnderIncentiveAndShareBasedCompensationPlansIncludingStockOptions, us-gaap_CommonStockSharesIssued, us-gaap_CommonStockSharesOutstanding, us-gaap_IncomeLossFromContinuingOperationsPerBasicShare, goog_AccruedRevenueShare, us-gaap_IncomeLossFromContinuingOperationsPerDilutedShare, goog_IncreaseDecreaseInAccruedRevenueShare, us-gaap_PaymentsToMinorityShareholders, us-gaap_CommonStockParOrStatedValuePerShare, us-gaap_TreasuryStockShares, us-gaap_TreasuryStockCommonShares, us-gaap_PreferredStockSharesAuthorized, us-gaap_CommonStockValueOutstanding, us-gaap_PreferredStockParOrStatedValuePerShare, us-gaap_CommonStockDividendsPerShareDeclared, us-gaap_SharePrice, lcid_IssuanceOfConvertiblePreferredShareContingentForwardContracts, us-gaap_WeightedAverageNumberDilutedSharesOutstandingAdjustment, us-gaap_AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount, smr_ProceedsFromExerciseOfWarrantsAndCommonShareOptions, smr_DepartmentOfEnergyCostShare, smr_OtherCostShareInterestExpense, smr_NetIncomeLossAttributableToLegacyShareholdersPriorToReverseRecapitalization, agnc_ComprehensiveIncomeAvailableToCommonShareholders, smr_IncreaseDecreaseInDepartmentOfEnergyCostShare, us-gaap_IncomeLossFromDiscontinuedOperationsNetOfTaxPerBasicShare, aes_IssuanceOfPreferredSharesInSubsidiaries, ionq_ReceiptsTaxWitholdingSharebasedPaymentArrangement, us-gaap_RestrictedStockValueSharesIssuedNetOfTaxWithholdings, rklb_TaxPaymentForNetSettledOptionShares, us-gaap_PreferredStockSharesOutstanding, us-gaap_IncomeLossFromDiscontinuedOperationsNetOfTaxPerDilutedShare, hood_UserHeldFractionalSharesAmount, hood_FractionalSharesRepurchaseObligationAmount, lcid_CapitalContributionUponIssuanceOfPreferredShares, us-gaap_EmployeeBenefitsAndShareBasedCompensationNoncash, us-gaap_WarrantsAndRightsOutstanding, us-gaap_PreferredStockSharesIssued, us-gaap_PreferredStockValueOutstanding, rklb_RepurchaseOfSharesAndOptionsFromManagement, rklb_WarrantsAndRightOutstanding
#
#    ❓ Uncategorized (263 concepts):
#       Total values: 4,764
#       Concepts: us-gaap_Goodwill, us-gaap_CommonStockValue, us-gaap_MinorityInterest, us-gaap_TreasuryStockValue, us-gaap_ShortTermBorrowings, us-gaap_PreferredStockValue, us-gaap_IncreaseDecreaseInDeposits, us-gaap_PreferredStockDividendsAndOtherAdjustments, us-gaap_OccupancyNet, us-gaap_Deposits, us-gaap_IncreaseDecreaseInTradingSecurities, us-gaap_FeesAndCommissionsMortgageBankingAndServicing, wfc_NetChangeInFederalFundsSoldSecuritiesPurchasedUnderResaleAgreementsAndOtherShortTermInvestments, wfc_FederalFundsSoldSecuritiesPurchasedUnderResaleAgreementsOtherShortTermInvestments, us-gaap_InterestBearingDepositsInBanks, wfc_FeesAndCommissionsOnDepositAccountsAndLendingActivities, wfc_OperatingLosses, wfc_TotalCreditAndDebitCardFees, us-gaap_RestructuringCharges, us-gaap_HeldToMaturitySecurities, us-gaap_TradingGainsLosses, wfc_CommissionAndIncentiveCompensation, us-gaap_SalariesWagesAndOfficersCompensation, us-gaap_IncreaseDecreaseInInventories, us-gaap_ProfitLoss, us-gaap_GrossProfit, us-gaap_ShortTermInvestments, wfc_InterestBearingDepositsInBanksAndOtherFinancialInstitutionsNetOfAllowanceForCreditLosses, us-gaap_MarketableSecuritiesCurrent, us-gaap_TreasuryStockCommonValue, us-gaap_LongTermInvestments, us-gaap_OtherLongTermInvestments, us-gaap_ProvisionForDoubtfulAccounts, msft_GainLossOnInvestmentsAndDerivativeInstruments, us-gaap_IncreaseDecreaseInDueToRelatedParties, us-gaap_ForeignCurrencyTransactionGainLossBeforeTax, us-gaap_GoodwillImpairmentLoss, us-gaap_FairValueAdjustmentOfWarrants, amd_GainLossOnLicensingAgreement, us-gaap_RelatedPartyTransactionDueFromToRelatedPartyCurrent, us-gaap_ConversionOfStockAmountConverted1, us-gaap_GainLossOnInvestments, us-gaap_ConstructionInProgressGross, us-gaap_RestructuringSettlementAndImpairmentProvisions, us-gaap_ForeignCurrencyTransactionGainLossUnrealized, us-gaap_InvestmentsInAffiliatesSubsidiariesAssociatesAndJointVentures, us-gaap_GainLossOnSaleOfBusiness, us-gaap_ProfessionalFees, us-gaap_MarketableSecuritiesNoncurrent, us-gaap_MarketableSecurities, us-gaap_DerivativeGainLossOnDerivativeNet, us-gaap_DisposalGroupNotDiscontinuedOperationGainLossOnDisposal, us-gaap_CommercialPaper, us-gaap_StockIssuedDuringPeriodValueConversionOfConvertibleSecuritiesNetOfAdjustments, us-gaap_IndefiniteLivedLicenseAgreements, us-gaap_Land, us-gaap_GainLossOnDerivativeInstrumentsNetPretax, us-gaap_StockIssued1, us-gaap_TransferToOtherRealEstate, us-gaap_IncreaseDecreaseInDueToAffiliates, rkt_IncreaseDecreaseInPremiumsAndIndemnification, rkt_MortgageServicingRightFairValueOnOrigination, us-gaap_DisposalGroupNotDiscontinuedOperationLossGainOnWriteDown, xom_AdditionalInvestmentsAndAdvances, us-gaap_DilutiveSecurities, amd_GainOnLicensingAgreement, ba_CustomerFinancingCurrent, ba_CustomerFinancingNoncurrent, lcid_IssuanceOfConvertiblePreferredStockUponSettlementOfContingentForwardContracts, lcid_IssuanceOfConvertiblePreferredStockUponExerciseOfPreferredStockWarrants, us-gaap_GainLossOnSaleOfInvestments, uber_RevaluationOnCallOption, dei_EntityCentralIndexKey, dei_DocumentFiscalYearFocus, us-gaap_MineralPropertiesNet, us-gaap_PremiumsEarnedNet, us-gaap_PolicyholderBenefitsAndClaimsIncurredHealthCare, smr_InProcessResearchAndDevelopment, nvda_BusinessCombinationAdvancedConsiderationWrittenOff, cde_OreOnLeachPadCurrent, us-gaap_SecuritiesSoldUnderAgreementsToRepurchase, ionq_BonusSettledInRestrictedStockUnits, agnc_Agencysecuritiestransferredtoconsolidatedvariableinterestentitiesatfairvalue, us-gaap_FinancialInstrumentsOwnedOtherAtFairValue, agnc_NonAgencySecuritiesatFairValue, us-gaap_AccruedEnvironmentalLossContingenciesNoncurrent, pcg_WildfireRelatedClaims, pcg_CustomerCreditTrust, us-gaap_DecommissioningFundInvestments, us-gaap_PensionAndOtherPostretirementBenefitContributions, aes_PurchasesUnderSupplierFinancingArrangements, aes_AcquisitionsOfNoncontrollingInterests, aes_ProvisionsForReversalsOfContingencies, aes_LossGainOnRemeasurementToAcquisitionDateFairValue, us-gaap_DividendsPreferredStock, r ...

# %%
# Explore concepts with and without descriptions
if not concepts_df.empty:
    print("📝 Financial Concepts Documentation:")

    # Count concepts with descriptions
    with_descriptions = concepts_df[concepts_df['description'].notna() & (concepts_df['description'] != '')]
    without_descriptions = concepts_df[concepts_df['description'].isna() | (concepts_df['description'] == '')]

    print(f"   Concepts with descriptions: {len(with_descriptions)} ({len(with_descriptions)/len(concepts_df)*100:.1f}%)")
    print(f"   Concepts without descriptions: {len(without_descriptions)} ({len(without_descriptions)/len(concepts_df)*100:.1f}%)")

    # Show concepts with labels
    with_labels = concepts_df[concepts_df['labels_count'] > 0]
    print(f"   Concepts with labels: {len(with_labels)} ({len(with_labels)/len(concepts_df)*100:.1f}%)")

    if not with_descriptions.empty:
        print("\n📖 Sample Concepts with Descriptions:")
        sample_with_desc = with_descriptions.head(5)
        for _, concept in sample_with_desc.iterrows():
            desc_preview = concept['description'][:100] + '...' if len(str(concept['description'])) > 100 else concept['description']
            print(f"   • {concept['name']}: {desc_preview}")

    if not without_descriptions.empty:
        print("\n❓ High-Usage Concepts Missing Descriptions:")
        missing_desc_high_usage = without_descriptions[without_descriptions['total_values'] > 10].head(10)
        if not missing_desc_high_usage.empty:
            print(missing_desc_high_usage[['name', 'total_values', 'companies_using']].to_string(index=False))
        else:
            print("   All high-usage concepts have descriptions!")

    # Export detailed concepts analysis
    output_file = '/home/steven/symbology/outputs/financial_concepts_analysis.csv'
    concepts_df.to_csv(output_file, index=False)
    print(f"\n💾 Detailed concepts analysis exported to: {output_file}")
else:
    print("⚠️  No concepts data available for documentation analysis")
# Out:
# 📝 Financial Concepts Documentation:
#    Concepts with descriptions: 1307 (100.0%)
#    Concepts without descriptions: 0 (0.0%)
#    Concepts with labels: 1307 (100.0%)
#
# 📖 Sample Concepts with Descriptions:
#    • us-gaap_Assets: Total Assets
#    • us-gaap_LiabilitiesAndStockholdersEquity: Total Liabilities and Stockholders' Equity
#    • us-gaap_RetainedEarningsAccumulatedDeficit: Retained Earnings
#    • us-gaap_EarningsPerShareBasic: Earnings Per Share
#    • us-gaap_EarningsPerShareDiluted: Earnings Per Share (Diluted)
#
# 💾 Detailed concepts analysis exported to: /home/steven/symbology/outputs/financial_concepts_analysis.csv

# %%
# Test the fix for the MARA ingestion error
print("🔧 Testing the fix for non-numeric value handling...")

# Try ingesting MARA again with the updated error handling
if edgar_ready:
    test_result_mara = ingest_company_financial_data('MARA', 2023, dry_run=False)

    print("\n📊 MARA Ingestion Results:")
    for key, value in test_result_mara.items():
        print(f"   {key}: {value}")

    if test_result_mara['success']:
        print("\n✅ Successfully fixed the numeric value validation issue!")
        print(f"   Financial values ingested: {test_result_mara.get('values_added', 0)}")
        if 'financial_data_counts' in test_result_mara:
            for statement_type, count in test_result_mara['financial_data_counts'].items():
                print(f"   {statement_type}: {count} values")
    else:
        print(f"\n❌ Still having issues: {test_result_mara['error']}")
else:
    print("⚠️  EDGAR access not configured")
# Out:
# 🔧 Testing the fix for non-numeric value handling...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2 print("🔧 Testing the fix for non-numeric value handling...")
#       4 # Try ingesting MARA again with the updated error handling
# ----> 5 if edgar_ready:
#       6     test_result_mara = ingest_company_financial_data('MARA', 2023, dry_run=False)
#       8     print("\n📊 MARA Ingestion Results:")
#
# NameError: name 'edgar_ready' is not defined

# %% [markdown]
# ## 4. Analysis of Duplicate Financial Concept Names
#
# Let's examine if there are any financial concepts with identical names in the database, which could indicate data quality issues or legitimate variations.

# %%
# Analyze duplicate financial concept names
if not concepts_df.empty:
    print("🔍 Analyzing Financial Concept Name Duplicates:")

    # Group by name and count occurrences
    name_counts = concepts_df['name'].value_counts()
    duplicate_names = name_counts[name_counts > 1]

    print(f"   Total unique concept names: {len(name_counts)}")
    print(f"   Total financial concepts: {len(concepts_df)}")
    print(f"   Names appearing multiple times: {len(duplicate_names)}")

    if len(duplicate_names) > 0:
        print(f"   Concepts with duplicate names: {duplicate_names.sum()} out of {len(concepts_df)}")
        print(f"   Percentage of concepts with duplicate names: {(duplicate_names.sum() / len(concepts_df)) * 100:.1f}%")

        print("\n📊 Duplicate Names Summary:")
        for name, count in duplicate_names.head(10).items():
            print(f"   '{name}': {count} concepts")

        # Show detailed analysis of duplicates
        print("\n📋 Detailed Analysis of Duplicate Concepts:")
        for name in duplicate_names.head(5).index:
            duplicate_concepts = concepts_df[concepts_df['name'] == name]
            print(f"\n   📌 Name: '{name}' ({len(duplicate_concepts)} concepts)")

            for _, concept in duplicate_concepts.iterrows():
                desc_preview = str(concept['description'])[:80] + '...' if len(str(concept['description'])) > 80 else str(concept['description'])
                print(f"      ID: {concept['id'][:8]}...")
                print(f"      Description: {desc_preview}")
                print(f"      Labels: {concept['labels']}")
                print(f"      Usage: {concept['total_values']} values, {concept['companies_using']} companies")
                print("      ---")

        # Create summary DataFrame for export
        duplicate_summary = []
        for name in duplicate_names.index:
            duplicate_concepts = concepts_df[concepts_df['name'] == name]
            for i, (_, concept) in enumerate(duplicate_concepts.iterrows()):
                duplicate_summary.append({
                    'concept_name': name,
                    'duplicate_number': i + 1,
                    'total_duplicates': len(duplicate_concepts),
                    'concept_id': concept['id'],
                    'description': concept['description'],
                    'labels': concept['labels'],
                    'total_values': concept['total_values'],
                    'companies_using': concept['companies_using']
                })

        duplicates_df = pd.DataFrame(duplicate_summary)
        output_file = '/home/steven/symbology/outputs/duplicate_financial_concepts.csv'
        duplicates_df.to_csv(output_file, index=False)
        print(f"\n💾 Detailed duplicate analysis exported to: {output_file}")

    else:
        print("\n✅ No duplicate concept names found!")
        print(f"   All {len(concepts_df)} financial concepts have unique names.")

    # Additional analysis: Similar names (potential typos or variations)
    print("\n🔤 Looking for Similar Names (potential variations):")
    concept_names = concepts_df['name'].tolist()
    similar_groups = []

    # Look for names that are very similar (differing by case, spaces, or punctuation)
    normalized_names = {}
    for name in concept_names:
        # Normalize: lowercase, remove spaces and underscores
        normalized = name.lower().replace('_', '').replace(' ', '').replace('-', '')
        if normalized in normalized_names:
            normalized_names[normalized].append(name)
        else:
            normalized_names[normalized] = [name]

    similar_groups = {norm: names for norm, names in normalized_names.items() if len(names) > 1}

    if similar_groups:
        print(f"   Found {len(similar_groups)} groups of similar names:")
        for i, (normalized, names) in enumerate(list(similar_groups.items())[:5]):
            print(f"      Group {i+1}: {names}")
        if len(similar_groups) > 5:
            print(f"      ... and {len(similar_groups) - 5} more groups")
    else:
        print("   No similar name patterns found.")

else:
    print("⚠️  No concepts data available for duplicate analysis")
